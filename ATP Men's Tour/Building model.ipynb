# %% [markdown]
# # 3. Building model
# Here we are going to build model for a players that will be playing match and we want to predict results.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Loading list of players

# %%
playersList = pd.Series.from_csv("Data/Players/PlayersList.csv")

# %% [markdown]
# ### Loading shortened history of games

# %%
games = pd.read_csv("Data/Raw.csv",encoding = "ISO-8859-1", low_memory=False)
#For now we are going to drop last 29 columns (betting odds data)
gamesNrCol = len(games.columns)
games.drop(games.columns[np.arange(gamesNrCol-29,gamesNrCol)], axis=1, inplace=True)
games.fillna(0, inplace=True)
#number of columns
gamesNrCol = len(games.columns)
print("# of columns {}".format(gamesNrCol))
#reversing dataset
games=games.iloc[::-1]
games=games.iloc[:250]

games.Date = pd.to_datetime(games.Date, format='%d/%m/%Y')
# Out:
# # of columns 25

# %% [markdown]
# ## Building model for a specific player, starts with specific moment

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier


def playerBuildModel(player, startsWithIndex):
    #playerDataset np.float64
    playerDataset = pd.read_csv("Data/Players/{}csv".format(player), index_col=0)
    
    """, dtype={
            "1LastGameDiff":np.float64,
            "1LastGameGamesDiff":np.float64,
            "2LastGameDiff":np.float64,
            "2LastGameGamesDiff":np.float64,
            "3LastGameDiff":np.float64,
            "3LastGameGamesDiff":np.float64,
            "4LastGameDiff":np.float64,
            "4LastGameGamesDiff":np.float64,
            "5LastGameDiff":np.float64,
            "5LastGameGamesDiff":np.float64,        
        }"""
    
    playerDataset.Date = pd.to_datetime(playerDataset.Date, format='%Y-%m-%d')
    #limit matches only to those before specific event
    playerDataset = prepareDataset(playerDataset)   
    
    #we have to limit nr of matches only to those before specific match
    playerDataset = playerDataset.loc[(startsWithIndex-1):]

    #how many matches he played
    matchesPlayed = len(playerDataset)
    
    #columns in dataset
    columns = playerDataset.columns
    
    #get rid of useless columns
    X = playerDataset[columns[2:-1]]
    y = playerDataset[columns[-1]]
    
    clf = RandomForestClassifier() 
    
    #clf = AdaBoostClassifier(DecisionTreeClassifier(max_depth=1),
    #                     algorithm="SAMME",
    #                     n_estimators=200)
    
    clf.fit(X,y)
    
    print("Model accuracy for {} is: {} with {} matches".format(player, clf.score(X,y), matchesPlayed))
    
    return (clf, playerDataset, matchesPlayed)

# %%
def prepareDataset(dataset):
    
    courts = [('Indoor', 0), ('Outdoor', 1)]
    surfaces = [('Clay', 0), ('Carpet', 1), ('Grass', 2), ('Hard', 3)]
    
    for court, i in courts: dataset.replace(court, i, inplace=True);
    for surface, i in surfaces: dataset.replace(surface, i, inplace=True);
    
    return dataset

games=prepareDataset(games)

# %%
def buildInputDataset(match, playerName, playerGames, predict = False):
    toReturn = []
    if not(predict):
        toReturn.append(match.ATP)
        toReturn.append(match.Date)
    #player rank, at the specific match
    rank = match.WRank if match.Winner == playerName else match.LRank
    toReturn.append(rank)
    
    #type of court
    court = 0 if match.Court == 'Indoor' else 1
    toReturn.append(court)
    
    #type of Surface
    if(match.Surface == 'Clay'): surface = 0;
    elif(match.Surface == 'Carpet'): surface = 1;
    elif(match.Surface == 'Grass'): surface = 2;
    else : surface = 3;
    toReturn.append(surface)
    
    #setting results for the last 5 games
    matchDate = match.Date
    for i in range(5):
        #result from last i-th game
        game = playerGames.iloc[i]
    
        if not(predict):
            #match results
            lastGameResult= 1 if game.Winner == playerName else 0
            
            #number od sets, number of won sets, sets difficultty
            sets = game.Wsets + game.Lsets
            wonSets = game.Wsets if game.Winner == playerName else game.Lsets
            setsDiff = wonSets/sets
            
            #number od games, number of won games, games difficultty
            nrOfGames = game.W1 + game.W2 +game.W3 + game.W4 + game.W5 + game.L1 + game.L2 + game.L3 + game.L4 + game.L5
            nrOfWonGames = game.W1 + game.W2 + game.W3 + game.W4 + game.W5 if game.Winner == playerName else game.L1 + game.L2 + game.L3 + game.L4 + game.L5
            gameDiff = nrOfWonGames / nrOfGames
            

            setsDiff = 0 if np.isnan(setsDiff) else setsDiff
            gameDiff = 0 if np.isnan(gameDiff) else gameDiff

            
        else:
            lastGameResult = game["{}LastGame".format(i+1)]
            setsDiff = game["{}LastGameDiff".format(i+1)]
            gameDiff = game["{}LastGameGamesDiff".format(i+1)]
            nrOfGames = game["{}LastGameNrOfGames".format(i+1)]

            
        lastGameDate = game.Date
        daysFree = matchDate - lastGameDate
        #Agregating history
        
        toReturn.append(daysFree.days)
        toReturn.append(lastGameResult)
        toReturn.append(setsDiff)
        toReturn.append(gameDiff)
        toReturn.append(nrOfGames)
        
        #new refference date
        matchDate = lastGameDate

    
    #calculating match in the tournament
    matchYear = match.Date.year
    Tournament = playerGames[ (playerGames['ATP'] == match.ATP) & (playerGames['Date'] >= '{}-1-1'.format(matchYear)) ]
    matchesInTour = len(Tournament)
    toReturn.append(matchesInTour)
    
    
    #depend wheater we want to predict result or we are building playerDataset
    if not(predict):
        #game result -> Player win=1 lose=0
        toReturn.append( int(1) if match.Winner == playerName else int(0))
  

    return toReturn

# %% [markdown]
# ## Testing algorythm

# %%
def testMatchResults(games, testSample=50, probDiff=0.1, minMatches=100):
    #nr of matches that we will be testing
    nrMatches = testSample

    #known results of matches
    matchResults = []
    #predicted results of matches
    matchPredResults = []
    #predicted probabilites
    matchProb = []

    for i in range(nrMatches):
        match = games.iloc[i]
        players= [match.Winner, match.Loser]

        print('='*80)
        print("Match: {} vs. {}".format(players[0], players[1]))
        print()
        #if we dont have enough data about one of two players then we skip it
        if players[0] not in playersList.values or players[1] not in playersList.values:
            continue

        #here we will save probabilities that specific player will win
        playersProbab = []
        matches =[]
        for player in players:

            #at first we will create model for a specific player
            playerModel, playerDataset, matchesPlayed = playerBuildModel(player, match.name)
            matches.append(matchesPlayed)
            #building input
            inputData = buildInputDataset(match, player, playerDataset,predict =True)

            #compute probability to win for a specific player
            prob = playerModel.predict_proba([inputData])

            #save probability to win
            playersProbab.append(prob[0][1])

        if(matches[0] < minMatches or matches[1] < minMatches):
            continue

        #compare probabilites to win for a specific players
        diff = playersProbab[0] - playersProbab[1]
        if abs(diff) > probDiff:
            #match results
            matchResults.append(0)
            print("Winner is {}".format(players[0]))
            
            if diff > 0: 
                matchPredResults.append(0)
                print("Predicted winner is {}".format(players[0]))
            else: 
                matchPredResults.append(1)
                print("Predicted winner is {}".format(players[1]))
            
            
            matchProb.append(playersProbab)

    return matchResults, matchPredResults, matchProb

# %% [markdown]
# ## Analysis test results

# %%
from sklearn import metrics

matchResults, matchPredResults, matchProb = testMatchResults(games, testSample=150, probDiff=0.2, minMatches=100)

test_score = metrics.accuracy_score(matchResults, matchPredResults)
print(test_score)
print(len(matchResults))
# Out:
# ================================================================================
# Match: Zverev A. vs. Wawrinka S.
#
# Model accuracy for Zverev A. is: 0.978494623655914 with 93 matches
# Model accuracy for Wawrinka S. is: 0.9890453834115805 with 639 matches
# ================================================================================
# Match: Wawrinka S. vs. Bautista Agut R.
#
# Model accuracy for Wawrinka S. is: 0.9890282131661442 with 638 matches
# Model accuracy for Bautista Agut R. is: 0.96 with 25 matches
# ================================================================================
# Match: Zverev A. vs. Berdych T.
#
# Model accuracy for Zverev A. is: 0.9782608695652174 with 92 matches
# Model accuracy for Berdych T. is: 0.9912390488110138 with 799 matches
# ================================================================================
# Match: Wawrinka S. vs. Troicki V.
#
# Model accuracy for Wawrinka S. is: 0.9921507064364207 with 637 matches
# Model accuracy for Troicki V. is: 0.992822966507177 with 418 matches
# Winner is Wawrinka S.
# Predicted winner is Wawrinka S.
# ================================================================================
# Match: Zverev A. vs. Youzhny M.
#
# Model accuracy for Zverev A. is: 0.9560439560439561 with 91 matches
# Model accuracy for Youzhny M. is: 0.9863692688971499 with 807 matches
# ================================================================================
# Match: Bautista Agut R. vs. Sousa J.
#
# Model accuracy for Bautista Agut R. is: 1.0 with 24 matches
# Model accuracy for Sousa J. is: 0.9748743718592965 with 199 matches
# ================================================================================
# Match: Berdych T. vs. Lorenzi P.
#
# Model accuracy for Berdych T. is: 0.9874686716791979 with 798 matches
# Model accuracy for Lorenzi P. is: 0.9819277108433735 with 166 matches
# Winner is Berdych T.
# Predicted winner is Berdych T.
# ================================================================================
# Match: Youzhny M. vs. Raonic M.
#
# Model accuracy for Youzhny M. is: 0.9789081885856079 with 806 matches
# Model accuracy for Raonic M. is: 0.9883720930232558 with 344 matches
# Winner is Youzhny M.
# Predicted winner is Raonic M.
# ================================================================================
# Match: Zverev A. vs. Medvedev D.
#
# ================================================================================
# Match: Berdych T. vs. Kuznetsov An.
#
# Model accuracy for Berdych T. is: 0.986198243412798 with 797 matches
# Model accuracy for Kuznetsov An. is: 0.9819819819819819 with 111 matches
# Winner is Berdych T.
# Predicted winner is Berdych T.
# ================================================================================
# Match: Troicki V. vs. Lajovic D.
#
# Model accuracy for Troicki V. is: 0.9832134292565947 with 417 matches
# Model accuracy for Lajovic D. is: 0.9818181818181818 with 110 matches
# Winner is Troicki V.
# Predicted winner is Troicki V.
# ================================================================================
# Match: Lorenzi P. vs. Sidorenko A.
#
# ================================================================================
# Match: Sousa J. vs. Rublev A.
#
# Model accuracy for Sousa J. is: 0.9797979797979798 with 198 matches
# Model accuracy for Rublev A. is: 1.0 with 19 matches
# ================================================================================
# Match: Bautista Agut R. vs. Berankis R.
#
# Model accuracy for Bautista Agut R. is: 0.9565217391304348 with 23 matches
# Model accuracy for Berankis R. is: 0.975609756097561 with 123 matches
# ================================================================================
# Match: Wawrinka S. vs. Rosol L.
#
# Model accuracy for Wawrinka S. is: 0.9842767295597484 with 636 matches
# Model accuracy for Rosol L. is: 0.9699570815450643 with 233 matches
# Winner is Wawrinka S.
# Predicted winner is Wawrinka S.
# ================================================================================
# Match: Kuznetsov An. vs. Donskoy E.
#
# Model accuracy for Kuznetsov An. is: 0.9818181818181818 with 110 matches
# Model accuracy for Donskoy E. is: 0.9746835443037974 with 79 matches
# ================================================================================
# Match: Troicki V. vs. Elias G.
#
# Model accuracy for Troicki V. is: 0.9759615384615384 with 416 matches
# Model accuracy for Elias G. is: 0.9696969696969697 with 33 matches
# ================================================================================
# Match: Youzhny M. vs. Tipsarevic J.
#
# Model accuracy for Youzhny M. is: 0.9925465838509316 with 805 matches
# Model accuracy for Tipsarevic J. is: 0.9838709677419355 with 434 matches
# ================================================================================
# Match: Sousa J. vs. Albot R.
#
# Model accuracy for Sousa J. is: 0.9695431472081218 with 197 matches
# Model accuracy for Albot R. is: 0.9333333333333333 with 15 matches
# ================================================================================
# Match: Rublev A. vs. Kukushkin M.
#
# Model accuracy for Rublev A. is: 1.0 with 18 matches
# Model accuracy for Kukushkin M. is: 0.9698492462311558 with 199 matches
# ================================================================================
# Match: Lajovic D. vs. Verdasco F.
#
# Model accuracy for Lajovic D. is: 0.9908256880733946 with 109 matches
# Model accuracy for Verdasco F. is: 0.9855263157894737 with 760 matches
# ================================================================================
# Match: Medvedev D. vs. Bublik A.
#
# ================================================================================
# Match: Lorenzi P. vs. Zverev M.
#
# Model accuracy for Lorenzi P. is: 0.9695121951219512 with 164 matches
# Model accuracy for Zverev M. is: 0.9732620320855615 with 187 matches
# ================================================================================
# Match: Sidorenko A. vs. Ramos-Vinolas A.
#
# ================================================================================
# Match: Zverev A. vs. Khachanov K.
#
# ================================================================================
# Match: Rosol L. vs. Schwartzman D.
#
# Model accuracy for Rosol L. is: 0.978448275862069 with 232 matches
# Model accuracy for Schwartzman D. is: 1.0 with 63 matches
# ================================================================================
# Match: Berankis R. vs. Mannarino A.
#
# Model accuracy for Berankis R. is: 0.9918032786885246 with 122 matches
# Model accuracy for Mannarino A. is: 0.9911504424778761 with 226 matches
# Winner is Berankis R.
# Predicted winner is Mannarino A.
# ================================================================================
# Match: Pouille L. vs. Thiem D.
#
# Model accuracy for Pouille L. is: 0.961038961038961 with 77 matches
# Model accuracy for Thiem D. is: 0.9946524064171123 with 187 matches
# ================================================================================
# Match: Pouille L. vs. Goffin D.
#
# Model accuracy for Pouille L. is: 1.0 with 76 matches
# Model accuracy for Goffin D. is: 0.9751243781094527 with 201 matches
# ================================================================================
# Match: Thiem D. vs. Simon G.
#
# Model accuracy for Thiem D. is: 0.9838709677419355 with 186 matches
# Model accuracy for Simon G. is: 0.9874804381846636 with 639 matches
# Winner is Thiem D.
# Predicted winner is Thiem D.
# ================================================================================
# Match: Goffin D. vs. Mahut N.
#
# Model accuracy for Goffin D. is: 0.975 with 200 matches
# Model accuracy for Mahut N. is: 0.9794117647058823 with 340 matches
# Winner is Goffin D.
# Predicted winner is Goffin D.
# ================================================================================
# Match: Pouille L. vs. Benneteau J.
#
# Model accuracy for Pouille L. is: 0.9866666666666667 with 75 matches
# Model accuracy for Benneteau J. is: 0.9940828402366864 with 507 matches
# ================================================================================
# Match: Thiem D. vs. Muller G.
#
# Model accuracy for Thiem D. is: 0.9891891891891892 with 185 matches
# Model accuracy for Muller G. is: 0.9836065573770492 with 305 matches
# ================================================================================
# Match: Simon G. vs. Jaziri M.
#
# Model accuracy for Simon G. is: 0.9796238244514106 with 638 matches
# Model accuracy for Jaziri M. is: 0.956989247311828 with 93 matches
# ================================================================================
# Match: Mahut N. vs. Marchenko I.
#
# Model accuracy for Mahut N. is: 0.9970501474926253 with 339 matches
# Model accuracy for Marchenko I. is: 0.9807692307692307 with 104 matches
# ================================================================================
# Match: Pouille L. vs. Herbert P.H.
#
# Model accuracy for Pouille L. is: 0.9864864864864865 with 74 matches
# Model accuracy for Herbert P.H. is: 1.0 with 27 matches
# ================================================================================
# Match: Goffin D. vs. Struff J.L.
#
# Model accuracy for Goffin D. is: 0.9748743718592965 with 199 matches
# Model accuracy for Struff J.L. is: 0.9876543209876543 with 81 matches
# ================================================================================
# Match: Simon G. vs. Garcia-Lopez G.
#
# Model accuracy for Simon G. is: 0.9874411302982732 with 637 matches
# Model accuracy for Garcia-Lopez G. is: 0.9928952042628775 with 563 matches
# Winner is Simon G.
# Predicted winner is Simon G.
# ================================================================================
# Match: Jaziri M. vs. Millot V.
#
# Model accuracy for Jaziri M. is: 0.9565217391304348 with 92 matches
# Model accuracy for Millot V. is: 1.0 with 15 matches
# ================================================================================
# Match: Muller G. vs. Basilashvili N.
#
# Model accuracy for Muller G. is: 0.9802631578947368 with 304 matches
# Model accuracy for Basilashvili N. is: 1.0 with 18 matches
# ================================================================================
# Match: Thiem D. vs. Gojowczyk P.
#
# Model accuracy for Thiem D. is: 0.9836956521739131 with 184 matches
# Model accuracy for Gojowczyk P. is: 1.0 with 20 matches
# ================================================================================
# Match: Benneteau J. vs. Brown D.
#
# Model accuracy for Benneteau J. is: 0.9861660079051383 with 506 matches
# Model accuracy for Brown D. is: 0.9734513274336283 with 113 matches
# ================================================================================
# Match: Jaziri M. vs. Dodig I.
#
# Model accuracy for Jaziri M. is: 0.967032967032967 with 91 matches
# Model accuracy for Dodig I. is: 0.9656652360515021 with 233 matches
# ================================================================================
# Match: Mahut N. vs. Halys Q.
#
# ================================================================================
# Match: Herbert P.H. vs. Cervantes I.
#
# Model accuracy for Herbert P.H. is: 0.8846153846153846 with 26 matches
# Model accuracy for Cervantes I. is: 1.0 with 38 matches
# ================================================================================
# Match: Struff J.L. vs. Robredo T.
#
# Model accuracy for Struff J.L. is: 0.975 with 80 matches
# Model accuracy for Robredo T. is: 0.9880382775119617 with 836 matches
# ================================================================================
# Match: Marchenko I. vs. Seppi A.
#
# Model accuracy for Marchenko I. is: 0.9805825242718447 with 103 matches
# Model accuracy for Seppi A. is: 0.9863713798977853 with 587 matches
# ================================================================================
# Match: Millot V. vs. Paire B.
#
# Model accuracy for Millot V. is: 1.0 with 14 matches
# Model accuracy for Paire B. is: 0.9918032786885246 with 244 matches
# ================================================================================
# Match: Brown D. vs. Mathieu P.H.
#
# Model accuracy for Brown D. is: 0.9821428571428571 with 112 matches
# Model accuracy for Mathieu P.H. is: 0.9760147601476015 with 542 matches
# ================================================================================
# Match: Garcia-Lopez G. vs. Dzumhur D.
#
# Model accuracy for Garcia-Lopez G. is: 0.9875444839857651 with 562 matches
# Model accuracy for Dzumhur D. is: 1.0 with 53 matches
# ================================================================================
# Match: Basilashvili N. vs. Barrere G.
#
# ================================================================================
# Match: Gojowczyk P. vs. Almagro N.
#
# Model accuracy for Gojowczyk P. is: 1.0 with 19 matches
# Model accuracy for Almagro N. is: 0.9887278582930756 with 621 matches
# ================================================================================
# Match: Muller G. vs. Zeballos H.
#
# Model accuracy for Muller G. is: 0.9801980198019802 with 303 matches
# Model accuracy for Zeballos H. is: 0.9655172413793104 with 145 matches
# ================================================================================
# Match: Benneteau J. vs. Klizan M.
#
# Model accuracy for Benneteau J. is: 0.9881188118811881 with 505 matches
# Model accuracy for Klizan M. is: 0.967032967032967 with 182 matches
# ================================================================================
# Match: Wawrinka S. vs. Djokovic N.
#
# Model accuracy for Wawrinka S. is: 0.9874015748031496 with 635 matches
# Model accuracy for Djokovic N. is: 0.991715976331361 with 845 matches
# Winner is Wawrinka S.
# Predicted winner is Djokovic N.
# ================================================================================
# Match: Wawrinka S. vs. Nishikori K.
#
# Model accuracy for Wawrinka S. is: 0.9858044164037855 with 634 matches
# Model accuracy for Nishikori K. is: 0.9924812030075187 with 399 matches
# ================================================================================
# Match: Djokovic N. vs. Monfils G.
#
# Model accuracy for Djokovic N. is: 0.9917061611374408 with 844 matches
# Model accuracy for Monfils G. is: 0.9895287958115183 with 573 matches
# Winner is Djokovic N.
# Predicted winner is Djokovic N.
# ================================================================================
# Match: Wawrinka S. vs. Del Potro J.M.
#
# Model accuracy for Wawrinka S. is: 0.9889415481832543 with 633 matches
# Model accuracy for Del Potro J.M. is: 0.9931662870159453 with 439 matches
# Winner is Wawrinka S.
# Predicted winner is Wawrinka S.
# ================================================================================
# Match: Nishikori K. vs. Murray A.
#
# Model accuracy for Nishikori K. is: 0.9899497487437185 with 398 matches
# Model accuracy for Murray A. is: 0.9931880108991825 with 734 matches
# Winner is Nishikori K.
# Predicted winner is Murray A.
# ================================================================================
# Match: Djokovic N. vs. Tsonga J.W.
#
# Model accuracy for Djokovic N. is: 0.9905100830367735 with 843 matches
# Model accuracy for Tsonga J.W. is: 0.9808795411089866 with 523 matches
# ================================================================================
# Match: Monfils G. vs. Pouille L.
#
# Model accuracy for Monfils G. is: 0.986013986013986 with 572 matches
# Model accuracy for Pouille L. is: 0.9863013698630136 with 73 matches
# ================================================================================
# Match: Murray A. vs. Dimitrov G.
#
# Model accuracy for Murray A. is: 0.984993178717599 with 733 matches
# Model accuracy for Dimitrov G. is: 0.9779874213836478 with 318 matches
# Winner is Murray A.
# Predicted winner is Murray A.
# ================================================================================
# Match: Nishikori K. vs. Karlovic I.
#
# Model accuracy for Nishikori K. is: 0.9899244332493703 with 397 matches
# Model accuracy for Karlovic I. is: 0.9844020797227037 with 577 matches
# ================================================================================
# Match: Wawrinka S. vs. Marchenko I.
#
# Model accuracy for Wawrinka S. is: 0.9889240506329114 with 632 matches
# Model accuracy for Marchenko I. is: 0.9803921568627451 with 102 matches
# ================================================================================
# Match: Del Potro J.M. vs. Thiem D.
#
# Model accuracy for Del Potro J.M. is: 0.9726027397260274 with 438 matches
# Model accuracy for Thiem D. is: 0.994535519125683 with 183 matches
# ================================================================================
# Match: Djokovic N. vs. Edmund K.
#
# Model accuracy for Djokovic N. is: 0.9881235154394299 with 842 matches
# Model accuracy for Edmund K. is: 0.9444444444444444 with 36 matches
# ================================================================================
# Match: Pouille L. vs. Nadal R.
#
# Model accuracy for Pouille L. is: 0.9583333333333334 with 72 matches
# Model accuracy for Nadal R. is: 0.9872881355932204 with 944 matches
# ================================================================================
# Match: Tsonga J.W. vs. Sock J.
#
# Model accuracy for Tsonga J.W. is: 0.9770114942528736 with 522 matches
# Model accuracy for Sock J. is: 0.9821428571428571 with 168 matches
# Winner is Tsonga J.W.
# Predicted winner is Tsonga J.W.
# ================================================================================
# Match: Monfils G. vs. Baghdatis M.
#
# Model accuracy for Monfils G. is: 0.9877408056042032 with 571 matches
# Model accuracy for Baghdatis M. is: 0.978515625 with 512 matches
# ================================================================================
# Match: Marchenko I. vs. Kyrgios N.
#
# Model accuracy for Marchenko I. is: 0.9702970297029703 with 101 matches
# Model accuracy for Kyrgios N. is: 0.9801980198019802 with 101 matches
# Winner is Marchenko I.
# Predicted winner is Kyrgios N.
# ================================================================================
# Match: Karlovic I. vs. Donaldson J.
#
# Model accuracy for Karlovic I. is: 0.9809027777777778 with 576 matches
# Model accuracy for Donaldson J. is: 1.0 with 24 matches
# ================================================================================
# Match: Nishikori K. vs. Mahut N.
#
# Model accuracy for Nishikori K. is: 0.9823232323232324 with 396 matches
# Model accuracy for Mahut N. is: 0.9821958456973294 with 337 matches
# ================================================================================
# Match: Wawrinka S. vs. Evans D.
#
# Model accuracy for Wawrinka S. is: 0.9889064976228209 with 631 matches
# Model accuracy for Evans D. is: 0.9393939393939394 with 33 matches
# ================================================================================
# Match: Murray A. vs. Lorenzi P.
#
# Model accuracy for Murray A. is: 0.9849726775956285 with 732 matches
# Model accuracy for Lorenzi P. is: 0.9693251533742331 with 163 matches
# ================================================================================
# Match: Del Potro J.M. vs. Ferrer D.
#
# Model accuracy for Del Potro J.M. is: 0.9862700228832952 with 437 matches
# Model accuracy for Ferrer D. is: 0.9875518672199171 with 964 matches
# Winner is Del Potro J.M.
# Predicted winner is Ferrer D.
# ================================================================================
# Match: Dimitrov G. vs. Sousa J.
#
# Model accuracy for Dimitrov G. is: 0.9747634069400631 with 317 matches
# Model accuracy for Sousa J. is: 0.9540816326530612 with 196 matches
# ================================================================================
# Match: Thiem D. vs. Carreno Busta P.
#
# Model accuracy for Thiem D. is: 1.0 with 182 matches
# Model accuracy for Carreno Busta P. is: 1.0 with 31 matches
# ================================================================================
# Match: Nadal R. vs. Kuznetsov An.
#
# Model accuracy for Nadal R. is: 0.9893955461293743 with 943 matches
# Model accuracy for Kuznetsov An. is: 0.981651376146789 with 109 matches
# ================================================================================
# Match: Edmund K. vs. Isner J.
#
# Model accuracy for Edmund K. is: 0.9428571428571428 with 35 matches
# Model accuracy for Isner J. is: 0.989406779661017 with 472 matches
# ================================================================================
# Match: Pouille L. vs. Bautista Agut R.
#
# Model accuracy for Pouille L. is: 0.9577464788732394 with 71 matches
# Model accuracy for Bautista Agut R. is: 1.0 with 22 matches
# ================================================================================
# Match: Djokovic N. vs. Youzhny M.
#
# Model accuracy for Djokovic N. is: 0.990487514863258 with 841 matches
# Model accuracy for Youzhny M. is: 0.9875621890547264 with 804 matches
# ================================================================================
# Match: Monfils G. vs. Almagro N.
#
# Model accuracy for Monfils G. is: 0.9824561403508771 with 570 matches
# Model accuracy for Almagro N. is: 0.9870967741935484 with 620 matches
# Winner is Monfils G.
# Predicted winner is Monfils G.
# ================================================================================
# Match: Sock J. vs. Cilic M.
#
# Model accuracy for Sock J. is: 1.0 with 167 matches
# Model accuracy for Cilic M. is: 0.9851301115241635 with 538 matches
# ================================================================================
# Match: Baghdatis M. vs. Harrison R.
#
# Model accuracy for Baghdatis M. is: 0.9882583170254403 with 511 matches
# Model accuracy for Harrison R. is: 0.9877300613496932 with 163 matches
# Winner is Baghdatis M.
# Predicted winner is Harrison R.
# ================================================================================
# Match: Tsonga J.W. vs. Anderson K.
#
# Model accuracy for Tsonga J.W. is: 0.9865642994241842 with 521 matches
# Model accuracy for Anderson K. is: 0.9822335025380711 with 394 matches
# ================================================================================
# Match: Karlovic I. vs. Young D.
#
# Model accuracy for Karlovic I. is: 0.9826086956521739 with 575 matches
# Model accuracy for Young D. is: 0.9578059071729957 with 237 matches
# ================================================================================
# Match: Ferrer D. vs. Fognini F.
#
# Model accuracy for Ferrer D. is: 0.9875389408099688 with 963 matches
# Model accuracy for Fognini F. is: 0.9770642201834863 with 436 matches
# ================================================================================
# Match: Marchenko I. vs. Dzumhur D.
#
# Model accuracy for Marchenko I. is: 0.98 with 100 matches
# Model accuracy for Dzumhur D. is: 0.9807692307692307 with 52 matches
# ================================================================================
# Match: Del Potro J.M. vs. Johnson S.
#
# Model accuracy for Del Potro J.M. is: 0.9931192660550459 with 436 matches
# Model accuracy for Johnson S. is: 0.9882352941176471 with 170 matches
# ================================================================================
# Match: Evans D. vs. Zverev A.
#
# Model accuracy for Evans D. is: 0.96875 with 32 matches
# Model accuracy for Zverev A. is: 1.0 with 88 matches
# ================================================================================
# Match: Wawrinka S. vs. Giannessi A.
#
# ================================================================================
# Match: Kyrgios N. vs. Zeballos H.
#
# Model accuracy for Kyrgios N. is: 0.99 with 100 matches
# Model accuracy for Zeballos H. is: 0.9791666666666666 with 144 matches
# Winner is Kyrgios N.
# Predicted winner is Kyrgios N.
# ================================================================================
# Match: Dimitrov G. vs. Chardy J.
#
# Model accuracy for Dimitrov G. is: 0.9810126582278481 with 316 matches
# Model accuracy for Chardy J. is: 0.9750623441396509 with 401 matches
# ================================================================================
# Match: Donaldson J. vs. Troicki V.
#
# Model accuracy for Donaldson J. is: 1.0 with 23 matches
# Model accuracy for Troicki V. is: 0.9855421686746988 with 415 matches
# ================================================================================
# Match: Lorenzi P. vs. Simon G.
#
# Model accuracy for Lorenzi P. is: 0.9753086419753086 with 162 matches
# Model accuracy for Simon G. is: 0.9952830188679245 with 636 matches
# ================================================================================
# Match: Sousa J. vs. Lopez F.
#
# Model accuracy for Sousa J. is: 0.9897435897435898 with 195 matches
# Model accuracy for Lopez F. is: 0.9883268482490273 with 771 matches
# ================================================================================
# Match: Thiem D. vs. Berankis R.
#
# Model accuracy for Thiem D. is: 0.988950276243094 with 181 matches
# Model accuracy for Berankis R. is: 0.9834710743801653 with 121 matches
# ================================================================================
# Match: Murray A. vs. Granollers M.
#
# Model accuracy for Murray A. is: 0.9917920656634747 with 731 matches
# Model accuracy for Granollers M. is: 0.9895287958115183 with 382 matches
# Winner is Murray A.
# Predicted winner is Murray A.
# ================================================================================
# Match: Carreno Busta P. vs. Tipsarevic J.
#
# Model accuracy for Carreno Busta P. is: 0.9666666666666667 with 30 matches
# Model accuracy for Tipsarevic J. is: 0.9815242494226328 with 433 matches
# ================================================================================
# Match: Nishikori K. vs. Khachanov K.
#
# ================================================================================
# Match: Mahut N. vs. Mathieu P.H.
#
# Model accuracy for Mahut N. is: 0.9880952380952381 with 336 matches
# Model accuracy for Mathieu P.H. is: 0.977818853974122 with 541 matches
# ================================================================================
# Match: Nadal R. vs. Seppi A.
#
# Model accuracy for Nadal R. is: 0.994692144373673 with 942 matches
# Model accuracy for Seppi A. is: 0.9658703071672355 with 586 matches
# ================================================================================
# Match: Bautista Agut R. vs. Delbonis F.
#
# Model accuracy for Bautista Agut R. is: 0.9523809523809523 with 21 matches
# Model accuracy for Delbonis F. is: 0.9790209790209791 with 143 matches
# ================================================================================
# Match: Pouille L. vs. Chiudinelli M.
#
# Model accuracy for Pouille L. is: 1.0 with 70 matches
# Model accuracy for Chiudinelli M. is: 0.9736842105263158 with 114 matches
# ================================================================================
# Match: Cilic M. vs. Stakhovsky S.
#
# Model accuracy for Cilic M. is: 0.9888268156424581 with 537 matches
# Model accuracy for Stakhovsky S. is: 0.9866220735785953 with 299 matches
# ================================================================================
# Match: Sock J. vs. Zverev M.
#
# Model accuracy for Sock J. is: 0.9578313253012049 with 166 matches
# Model accuracy for Zverev M. is: 0.9623655913978495 with 186 matches
# Winner is Sock J.
# Predicted winner is Sock J.
# ================================================================================
# Match: Kuznetsov An. vs. Ramos-Vinolas A.
#
# Model accuracy for Kuznetsov An. is: 0.9814814814814815 with 108 matches
# Model accuracy for Ramos-Vinolas A. is: 0.9595959595959596 with 99 matches
# ================================================================================
# Match: Almagro N. vs. Cuevas P.
#
# Model accuracy for Almagro N. is: 0.9822294022617124 with 619 matches
# Model accuracy for Cuevas P. is: 0.9799196787148594 with 249 matches
# ================================================================================
# Match: Monfils G. vs. Satral J.
#
# ================================================================================
# Match: Youzhny M. vs. Pella G.
#
# Model accuracy for Youzhny M. is: 0.9838107098381071 with 803 matches
# Model accuracy for Pella G. is: 1.0 with 56 matches
# ================================================================================
# Match: Djokovic N. vs. Vesely J.
#
# Model accuracy for Djokovic N. is: 0.9916666666666667 with 840 matches
# Model accuracy for Vesely J. is: 0.9830508474576272 with 118 matches
# Winner is Djokovic N.
# Predicted winner is Djokovic N.
# ================================================================================
# Match: Harrison R. vs. Raonic M.
#
# Model accuracy for Harrison R. is: 0.9938271604938271 with 162 matches
# Model accuracy for Raonic M. is: 0.9883381924198251 with 343 matches
# Winner is Harrison R.
# Predicted winner is Raonic M.
# ================================================================================
# Match: Baghdatis M. vs. Paire B.
#
# Model accuracy for Baghdatis M. is: 0.9882352941176471 with 510 matches
# Model accuracy for Paire B. is: 0.9835390946502057 with 243 matches
# Winner is Baghdatis M.
# Predicted winner is Baghdatis M.
# ================================================================================
# Match: Tsonga J.W. vs. Duckworth J.
#
# Model accuracy for Tsonga J.W. is: 0.9961538461538462 with 520 matches
# Model accuracy for Duckworth J. is: 1.0 with 47 matches
# ================================================================================
# Match: Isner J. vs. Darcis S.
#
# Model accuracy for Isner J. is: 0.9957537154989384 with 471 matches
# Model accuracy for Darcis S. is: 0.9745222929936306 with 157 matches
# ================================================================================
# Match: Anderson K. vs. Pospisil V.
#
# Model accuracy for Anderson K. is: 0.9949109414758269 with 393 matches
# Model accuracy for Pospisil V. is: 0.9879518072289156 with 166 matches
# ================================================================================
# Match: Edmund K. vs. Escobedo E.
#
# ================================================================================
# Match: Murray A. vs. Rosol L.
#
# Model accuracy for Murray A. is: 0.9945205479452055 with 730 matches
# Model accuracy for Rosol L. is: 0.9783549783549783 with 231 matches
# Winner is Murray A.
# Predicted winner is Murray A.
# ================================================================================
# Match: Marchenko I. vs. Dodig I.
#
# Model accuracy for Marchenko I. is: 0.9090909090909091 with 99 matches
# Model accuracy for Dodig I. is: 0.978448275862069 with 232 matches
# ================================================================================
# Match: Berankis R. vs. Jaziri M.
#
# Model accuracy for Berankis R. is: 0.9583333333333334 with 120 matches
# Model accuracy for Jaziri M. is: 0.9666666666666667 with 90 matches
# ================================================================================
# Match: Kyrgios N. vs. Bedene A.
#
# Model accuracy for Kyrgios N. is: 1.0 with 99 matches
# Model accuracy for Bedene A. is: 0.9819819819819819 with 111 matches
# ================================================================================
# Match: Lorenzi P. vs. Berlocq C.
#
# Model accuracy for Lorenzi P. is: 0.9565217391304348 with 161 matches
# Model accuracy for Berlocq C. is: 0.9661654135338346 with 266 matches
# ================================================================================
# Match: Simon G. vs. Stepanek R.
#
# Model accuracy for Simon G. is: 0.9905511811023622 with 635 matches
# Model accuracy for Stepanek R. is: 0.9855305466237942 with 622 matches
# ================================================================================
# Match: Granollers M. vs. Monaco J.
#
# Model accuracy for Granollers M. is: 0.989501312335958 with 381 matches
# Model accuracy for Monaco J. is: 0.9893992932862191 with 566 matches
# ================================================================================
# Match: Thiem D. vs. Millman J.
#
# Model accuracy for Thiem D. is: 0.9888888888888889 with 180 matches
# Model accuracy for Millman J. is: 0.9811320754716981 with 53 matches
# ================================================================================
# Match: Johnson S. vs. Donskoy E.
#
# Model accuracy for Johnson S. is: 0.9763313609467456 with 169 matches
# Model accuracy for Donskoy E. is: 0.9487179487179487 with 78 matches
# ================================================================================
# Match: Young D. vs. Struff J.L.
#
# Model accuracy for Young D. is: 0.9745762711864406 with 236 matches
# Model accuracy for Struff J.L. is: 0.9493670886075949 with 79 matches
# ================================================================================
# Match: Del Potro J.M. vs. Schwartzman D.
#
# Model accuracy for Del Potro J.M. is: 0.9862068965517241 with 435 matches
# Model accuracy for Schwartzman D. is: 0.9838709677419355 with 62 matches
# ================================================================================
# Match: Karlovic I. vs. Lu Y.H.
#
# Model accuracy for Karlovic I. is: 0.9790940766550522 with 574 matches
# Model accuracy for Lu Y.H. is: 0.98125 with 320 matches
# ================================================================================
# Match: Zeballos H. vs. Mayer F.
#
# Model accuracy for Zeballos H. is: 0.965034965034965 with 143 matches
# Model accuracy for Mayer F. is: 0.9857482185273159 with 421 matches
# ================================================================================
# Match: Lopez F. vs. Coric B.
#
# Model accuracy for Lopez F. is: 0.9883116883116884 with 770 matches
# Model accuracy for Coric B. is: 0.9795918367346939 with 98 matches
# ================================================================================
# Match: Dzumhur D. vs. Tomic B.
#
# Model accuracy for Dzumhur D. is: 0.9607843137254902 with 51 matches
# Model accuracy for Tomic B. is: 0.9664179104477612 with 268 matches
# ================================================================================
# Match: Sousa J. vs. Estrella Burgos V.
#
# Model accuracy for Sousa J. is: 0.9742268041237113 with 194 matches
# Model accuracy for Estrella Burgos V. is: 0.9866666666666667 with 75 matches
# ================================================================================
# Match: Mathieu P.H. vs. Harrison C.
#
# ================================================================================
# Match: Fognini F. vs. Gabashvili T.
#
# Model accuracy for Fognini F. is: 0.9908045977011494 with 435 matches
# Model accuracy for Gabashvili T. is: 0.9898305084745763 with 295 matches
# ================================================================================
# Match: Donaldson J. vs. Goffin D.
#
# Model accuracy for Donaldson J. is: 1.0 with 22 matches
# Model accuracy for Goffin D. is: 1.0 with 198 matches
# ================================================================================
# Match: Ferrer D. vs. Dolgopolov O.
#
# Model accuracy for Ferrer D. is: 0.9916839916839917 with 962 matches
# Model accuracy for Dolgopolov O. is: 0.9770114942528736 with 348 matches
# Winner is Ferrer D.
# Predicted winner is Ferrer D.
# ================================================================================
# Match: Giannessi A. vs. Kudla D.
#
# ================================================================================
# Match: Wawrinka S. vs. Verdasco F.
#
# Model accuracy for Wawrinka S. is: 0.9825119236883942 with 629 matches
# Model accuracy for Verdasco F. is: 0.9934123847167325 with 759 matches
# Winner is Wawrinka S.
# Predicted winner is Wawrinka S.
# ================================================================================
# Match: Mahut N. vs. Kohlschreiber P.
#
# Model accuracy for Mahut N. is: 0.9731343283582089 with 335 matches
# Model accuracy for Kohlschreiber P. is: 0.9827856025039123 with 639 matches
# ================================================================================
# Match: Tipsarevic J. vs. Querrey S.
#
# Model accuracy for Tipsarevic J. is: 0.9861111111111112 with 432 matches
# Model accuracy for Querrey S. is: 0.9854771784232366 with 482 matches
# Winner is Tipsarevic J.
# Predicted winner is Querrey S.
# ================================================================================
# Match: Troicki V. vs. Albot R.
#
# Model accuracy for Troicki V. is: 0.9879227053140096 with 414 matches
# Model accuracy for Albot R. is: 0.9285714285714286 with 14 matches
# ================================================================================
# Match: Chardy J. vs. Mmoh M.
#
# ================================================================================
# Match: Carreno Busta P. vs. Ivashka I.
#
# ================================================================================
# Match: Zverev A. vs. Brands D.
#
# Model accuracy for Zverev A. is: 0.9540229885057471 with 87 matches
# Model accuracy for Brands D. is: 0.9635036496350365 with 137 matches
# ================================================================================
# Match: Nishikori K. vs. Becker B.
#
# Model accuracy for Nishikori K. is: 0.9847715736040609 with 394 matches
# Model accuracy for Becker B. is: 0.9804469273743017 with 358 matches
# ================================================================================
# Match: Khachanov K. vs. Fabbiano T.
#
# ================================================================================
# Match: Evans D. vs. Ram R.
#
# Model accuracy for Evans D. is: 0.9354838709677419 with 31 matches
# Model accuracy for Ram R. is: 0.9496402877697842 with 139 matches
# ================================================================================
# Match: Dimitrov G. vs. Cervantes I.
#
# Model accuracy for Dimitrov G. is: 0.9746031746031746 with 315 matches
# Model accuracy for Cervantes I. is: 0.972972972972973 with 37 matches
# ================================================================================
# Match: Djokovic N. vs. Janowicz J.
#
# Model accuracy for Djokovic N. is: 0.9904648390941597 with 839 matches
# Model accuracy for Janowicz J. is: 0.9794520547945206 with 146 matches
# Winner is Djokovic N.
# Predicted winner is Djokovic N.
# 0.709677419355
# 31

# %% [markdown]
# ## Finding the 98% accuracy parameters

# %%
probabDiffs = np.arange(0, 0.3, 0.02)
minMatchess = range(50, 250, 10)

from IPython.core.display import clear_output
x=[]
y=[]
z=[]
k=[]
for i in probabDiffs:
    for j in minMatchess:
        matchResults, matchPredResults, matchProb = testMatchResults(games, testSample=200, probDiff=i, minMatches=j)
        test_score = metrics.accuracy_score(matchResults, matchPredResults)
        x.append(i)
        y.append(j)
        z.append(test_score)
        k.append(len(matchResults))
        clear_output()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib qt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(x, y, z)

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(x, y, k)
plt.show()
